# %%
import pickle
import pprint
with open('mnist_results.pkl', 'rb') as f:
    data = pickle.load(f)
pprint.pprint(data)
# Out:
# {'caps_history': {'acc': [np.float64(0.966796875),
#                           np.float64(0.9874588815789473),
#                           np.float64(0.9906455592105263),
#                           np.float64(0.9935238486842105),
#                           np.float64(0.992907072368421),
#                           np.float64(0.9919819078947368),
#                           np.float64(0.9937294407894737),
#                           np.float64(0.993421052631579),
#                           np.float64(0.9933182565789473),
#                           np.float64(0.9940378289473685),
#                           np.float64(0.9942434210526315),
#                           np.float64(0.9936266447368421),
#                           np.float64(0.9935238486842105),
#                           np.float64(0.9940378289473685),
#                           np.float64(0.9940378289473685),
#                           np.float64(0.9939350328947368),
# ...
